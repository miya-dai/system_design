# %%
import os 
os.listdir("./xevals")
# Out:
# ['xeval_1000_1.csv',
#  'xeval_1000_10.csv',
#  'xeval_1000_2.csv',
#  'xeval_1000_3.csv',
#  'xeval_1000_4.csv',
#  'xeval_1000_5.csv',
#  'xeval_1000_6.csv',
#  'xeval_1000_7.csv',
#  'xeval_1000_8.csv',
#  'xeval_1000_9.csv',
#  'xeval_100_1.csv',
#  'xeval_100_10.csv',
#  'xeval_100_2.csv',
#  'xeval_100_3.csv',
#  'xeval_100_4.csv',
#  'xeval_100_5.csv',
#  'xeval_100_6.csv',
#  'xeval_100_7.csv',
#  'xeval_100_8.csv',
#  'xeval_100_9.csv',
#  'xeval_10_1.csv',
#  'xeval_10_10.csv',
#  'xeval_10_2.csv',
#  'xeval_10_3.csv',
#  'xeval_10_4.csv',
#  'xeval_10_5.csv',
#  'xeval_10_6.csv',
#  'xeval_10_7.csv',
#  'xeval_10_8.csv',
#  'xeval_10_9.csv',
#  'xeval_200_1.csv',
#  'xeval_200_10.csv',
#  'xeval_200_2.csv',
#  'xeval_200_3.csv',
#  'xeval_200_4.csv',
#  'xeval_200_5.csv',
#  'xeval_200_6.csv',
#  'xeval_200_7.csv',
#  'xeval_200_8.csv',
#  'xeval_200_9.csv',
#  'xeval_20_1.csv',
#  'xeval_20_10.csv',
#  'xeval_20_2.csv',
#  'xeval_20_3.csv',
#  'xeval_20_4.csv',
# ...
